# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("../input/netflix-subscription-price-in-different-countries/netflix price in different countries.csv")

# %% [markdown]
# # **Data Questioning**

# %%
data.head()
# Out:
#      Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0  Argentina                4760             3154           1606
# 1    Austria                5640             3779           1861
# 2    Bolivia                4991             3155           1836
# 3   Bulgaria                6797             4819           1978
# 4      Chile                4994             3156           1838
#
#    Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                        3.74                           6.30
# 1                        9.03                          14.67
# 2                        7.99                          10.99
# 3                        9.03                          11.29
# 4                        7.07                           9.91
#
#    Cost Per Month - Premium ($)
# 0                          9.26
# 1                         20.32
# 2                         13.99
# 3                         13.54
# 4                         12.74

# %%
data.columns
# Out:
# Index(['Country', 'Total Library Size', 'No. of TV Shows', 'No. of Movies',
#        'Cost Per Month - Basic ($)', 'Cost Per Month - Standard ($)',
#        'Cost Per Month - Premium ($)'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        65 non-null     object
#  1   Total Library Size             65 non-null     int64
#  2   No. of TV Shows                65 non-null     int64
#  3   No. of Movies                  65 non-null     int64
#  4   Cost Per Month - Basic ($)     65 non-null     float64
#  5   Cost Per Month - Standard ($)  65 non-null     float64
#  6   Cost Per Month - Premium ($)   65 non-null     float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.7+ KB

# %%
data.describe()
# Out:
#        Total Library Size  No. of TV Shows  No. of Movies  \
# count           65.000000        65.000000      65.000000
# mean          5314.415385      3518.953846    1795.461538
# std            980.322633       723.010556     327.279748
# min           2274.000000      1675.000000     373.000000
# 25%           4948.000000      3154.000000    1628.000000
# 50%           5195.000000      3512.000000    1841.000000
# 75%           5952.000000      3832.000000    1980.000000
# max           7325.000000      5234.000000    2387.000000
#
#        Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# count                   65.000000                      65.000000
# mean                     8.368462                      11.990000
# std                      1.937819                       2.863979
# min                      1.970000                       3.000000
# 25%                      7.990000                      10.710000
# ...

# %%
data.Country.unique()
# Out:
# array(['Argentina', 'Austria', 'Bolivia', 'Bulgaria', 'Chile', 'Colombia',
#        'Costa Rica', 'Croatia', 'Czechia', 'Ecuador', 'Estonia', 'France',
#        'Germany', 'Gibraltar', 'Greece', 'Guatemala', 'Honduras',
#        'Hong Kong', 'Iceland', 'India', 'Israel', 'Italy', 'Japan',
#        'Liechtenstein', 'Malaysia', 'Mexico', 'Moldova', 'Monaco',
#        'Norway', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Romania',
#        'Russia', 'San Marino', 'Slovakia', 'South Africa', 'South Korea',
#        'Taiwan', 'Thailand', 'Turkey', 'Ukraine', 'Uruguay', 'Venezuela',
#        'Belgium', 'Singapore', 'Finland', 'Latvia', 'New Zealand',
#        'Hungary', 'Portugal', 'Netherlands', 'Sweden', 'Canada',
#        'Lithuania', 'Spain', 'United Kingdom', 'Indonesia', 'Brazil',
#        'Ireland', 'Switzerland', 'Australia', 'Denmark', 'United States'],
#       dtype=object)

# %% [markdown]
# #  Empty value Query

# %%
data.notnull().all()
# Out:
# Country                          True
# Total Library Size               True
# No. of TV Shows                  True
# No. of Movies                    True
# Cost Per Month - Basic ($)       True
# Cost Per Month - Standard ($)    True
# Cost Per Month - Premium ($)     True
# dtype: bool

# %%
data.isnull().sum()
# Out:
# Country                          0
# Total Library Size               0
# No. of TV Shows                  0
# No. of Movies                    0
# Cost Per Month - Basic ($)       0
# Cost Per Month - Standard ($)    0
# Cost Per Month - Premium ($)     0
# dtype: int64

# %% [markdown]
# # **Data Visualization**

# %%
#Correlation Map
f,ax=plt.subplots(figsize=(15,15))
sns.heatmap(data.corr(),annot=True,linewidths=.5,fmt='.1f',ax=ax)
plt.show()

# %%
#Histogram Plot
def hist(a):
    plt.hist(data[a],bins=10)
    plt.xlabel(a)
    plt.ylabel("Frequency")
    plt.show()

numericvalue=["Total Library Size","No. of Movies","No. of TV Shows",]    
for i in numericvalue:
    hist(i)

# %%
plt.figure(figsize=(15,10))
plt.bar(data["Country"],data["Total Library Size"])
plt.xlabel("Country")
plt.ylabel("Total Library Size")

plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(data["Country"],data["No. of TV Shows"])
plt.xlabel("Country")
plt.ylabel("No. of TV Shows")

plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(data["Country"],data["No. of Movies"])
plt.xlabel("Country")
plt.ylabel("No. of Movies")

plt.xticks(rotation=90)
plt.show()

# %%
#Line plot

plt.figure(figsize=(15,10))
plt.plot(data["Country"],data["Cost Per Month - Basic ($)"],color="red")
plt.plot(data["Country"],data["Cost Per Month - Standard ($)"],color="blue")
plt.plot(data["Country"],data["Cost Per Month - Premium ($)"],color="green")
plt.xticks(rotation=90)
plt.show()

# %%
#Scatter Plot
plt.figure(figsize=(15,10))
plt.scatter('Country',"Cost Per Month - Basic ($)" , data=data,color="red")
plt.scatter('Country',"Cost Per Month - Standard ($)" , data=data,color="blue")
plt.scatter('Country',"Cost Per Month - Premium ($)" , data=data,color="green")
plt.xticks(rotation=90)

plt.show()

# %%
#Line plot

plt.figure(figsize=(15,10))
plt.plot(data["Country"],data["No. of TV Shows"],color="red")
plt.plot(data["Country"],data["No. of Movies"],color="blue")

plt.xticks(rotation=90)
plt.show()

# %%
#Scatter Plot
plt.figure(figsize=(15,10))
plt.scatter('Country',"No. of TV Shows" , data=data,color="red")
plt.scatter('Country',"No. of Movies" , data=data,color="blue")

plt.xticks(rotation=90)

plt.show()
